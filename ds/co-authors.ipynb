# %%
import pandas as pd
from tqdm.notebook import tqdm as tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from collections import defaultdict
from collections import Counter
from langdetect import detect
import re
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
# %matplotlib inline

# %%
FILE_ORIGIN = '../dblpv13.json'
FILE_PREPROCESSED = '../data.json'

# %%
CHUNKSIZE = 100000
MAX_OBSERVATIONS = 1000000 #Set to 55000000 if want all rows
df = pd.DataFrame()
with pd.read_json(FILE_PREPROCESSED, orient='records', lines=True, chunksize=CHUNKSIZE, nrows=MAX_OBSERVATIONS) as reader:
    for chunk_i, chunk in tqdm_notebook(enumerate(reader), total=MAX_OBSERVATIONS // CHUNKSIZE):
        df_new = pd.DataFrame(chunk)
        df_new['chunk_idx'] = chunk_i
        df = pd.concat([df, df_new], ignore_index=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                         _id  \
# 0  53e99784b7602d9701f3e3f5
# 1  53e99784b7602d9701f3e133
# 2  53e99784b7602d9701f3e151
# 3  53e99784b7602d9701f3e15d
# 4  53e99784b7602d9701f3e161
#
#                                                title  \
# 0                                              3GIO.
# 1  The relationship between canopy parameters and...
# 2  A solution to the problem of touching and brok...
# 3  Timing yield estimation using statistical stat...
# 4                                               360°
#
#                                                venue    year  \
# 0                                        {'type': 0}  2011.0
# 1  {'_id': '53a7297d20f7420be8bd4ae7', 'name_d': ...  2011.0
# 2  {'_id': '53a72a4920f7420be8bfa51b', 'name_d': ...  1993.0
# 3  {'_id': '53a72e2020f7420be8c80142', 'name_d': ...  2005.0
# 4  {'_id': '5390a74a20f70186a0e8b40b', 'raw': 'AC...  2009.0
#
#                                             keywords  n_citation lang  \
# 0                                                 []         0.0   en
# 1  [canopy parameters, canopy spectrum, different...         0.0   en
# 2  [handwriting recognition, prototypes, image se...        17.0   en
# 3  [sequential circuits, statistical distribution...        28.0   en
# 4  [global high technology, daily short-distance ...         NaN   en
#
#                                              authors  \
# 0                                                NaN
# 1  [{'_id': '53f45728dabfaec09f209538', 'name': '...
# 2  [{'_id': '53f46797dabfaeb22f542630', 'name': '...
# 3  [{'_id': '53f43b03dabfaedce555bf2a', 'name': '...
# 4  [{'_id': '53f46946dabfaec09f24b4ed', 'name': '...
#
#                                                  fos page_start  ... volume  \
# 0                                                NaN        NaN  ...    NaN
# 1  [Agronomy, Moisture, Hydrology, Environmental ...       1930  ...   null
# 2  [Intelligent character recognition, Pattern re...        602  ...
# 3  [Delay calculation, Timing failure, Monte Carl...       2461  ...
# 4                                                NaN         39  ...
#
#   issue issn           isbn                          doi  \
# 0   NaN  NaN            NaN                          NaN
# 1  null                      10.1109/IGARSS.2011.6049503
# 2                              10.1109/ICDAR.1993.395663
# 3             0-7803-8834-8   10.1109/ISCAS.2005.1465124
# 4                                10.1145/1665137.1665166
#
#                                                  pdf  \
# 0                                                NaN
# 1                                               None
# 2                                               None
# 3  //static.aminer.org/pdf/PDF/000/423/329/timing...
# 4                                                NaN
#
#                                                  url  \
# 0                                                NaN
# 1    [http://dx.doi.org/10.1109/IGARSS.2011.6049503]
# 2      [http://dx.doi.org/10.1109/ICDAR.1993.395663]
# 3  [http://dx.doi.org/10.1109/ISCAS.2005.1465124,...
# 4                                                NaN
#
#                                             abstract  \
# 0                                                NaN
# 1  Drought is the first place in all the natural ...
# 2
# 3  As process variations become a significant pro...
# 4  360° represents the concerns that are addresse...
#
#                                           references chunk_idx
# 0                                                NaN         0
# 1                                                NaN         0
# 2  [53e99cf5b7602d97025ace63, 557e8a7a6fee0fe990c...         0
# 3  [53e9a8a9b7602d97031f6bb9, 599c7b6b601a182cd27...         0
# 4                                                NaN         0
#
# [5 rows x 21 columns]

# %%
authors = Counter()
for val in df['authors']:
    if isinstance(val, list):
        for author in val:
            if 'name' in author and re.match(r'^[a-zA-Z\s\-\.\,]+$', author['name']):
                authors[author['name']] += 1

# %%
top_n_authors = dict(authors.most_common(30000))

# %%
top_n_authors
# Out:
# {'Wei Wang': 602,
#  'Lei Zhang': 415,
#  'Wei Zhang': 405,
#  'Wei Li': 363,
#  'Yang Liu': 336,
#  'Lei Wang': 330,
#  'Jun Wang': 318,
#  'Li Zhang': 313,
#  'Yan Zhang': 302,
#  'Wen Gao': 292,
#  'Jun Zhang': 291,
#  'Wei Liu': 273,
#  'Ming Li': 262,
#  'Xin Li': 262,
#  'Jun Li': 255,
#  'Jing Li': 254,
#  'Jiawei Han': 242,
#  'Li Li': 241,
#  'Wei Chen': 236,
#  'Yu Wang': 233,
#  'Elisa Bertino': 232,
#  'Jing Wang': 232,
#  'Bo Li': 231,
#  'Philip S. Yu': 228,
#  'Thomas S. Huang': 226,
#  'Tao Li': 225,
#  'Yu Zhang': 224,
#  'Hai Jin': 222,
#  'Hui Li': 222,
#  'Hui Wang': 217,
#  'Witold Pedrycz': 217,
#  'Xin Wang': 213,
#  'Bin Li': 210,
#  'Jie Wu': 206,
#  'Chin-Chen Chang': 206,
#  'Jie Zhang': 205,
#  'Mario Piattini': 202,
#  'Yong Wang': 201,
#  'Ajith Abraham': 200,
#  'Jian Li': 198,
#  'Yi Zhang': 197,
#  'Edwin R. Hancock': 197,
#  'H. Vincent Poor': 197,
#  'Yang Yang': 197,
#  'Jing Zhang': 197,
#  'Ying Zhang': 196,
#  'Bin Wang': 195,
#  'Qing Li': 195,
#  'Ping Zhang': 195,
#  'Rui Zhang': 194,
#  'Jie Yang': 194,
#  'Xiang Li': 193,
#  'Yi Wang': 193,
#  'Xiaodong Wang': 192,
#  'Jian Zhang': 190,
#  'Leonard Barolli': 187,
#  'Xin Zhang': 187,
#  'Lei Chen': 186,
#  'Jian Wang': 186,
#  'Hui Zhang': 185,
#  'Peng Li': 185,
#  'Jun Liu': 184,
#  'Jian Yang': 184,
#  'Yan Li': 181,
#  'Moshe Y. Vardi': 180,
#  'Hong Zhang': 175,
#  'Yan Wang': 175,
#  'Mario Gerla': 175,
#  'Lajos Hanzo': 174,
#  'Ying Li': 174,
#  'Ying Liu': 174,
#  'Chao Wang': 173,
#  'Hao Wang': 173,
#  'Bo Zhang': 172,
#  'Makoto Takizawa': 171,
#  'Ying Wang': 170,
#  'Tao Jiang': 169,
#  'Bin Liu': 169,
#  'Noga Alon': 166,
#  'Li Chen': 166,
#  'Sajal K. Das': 166,
#  'Yan Chen': 166,
#  'Yang Li': 165,
#  'Bo Yang': 164,
#  'Jing Liu': 164,
#  'Hermann Ney': 164,
#  'Grzegorz Rozenberg': 163,
#  'Henri Prade': 163,
#  'Hao Zhang': 162,
#  'Jun Yang': 162,
#  'Ralf Steinmetz': 162,
#  'Christos Faloutsos': 161,
#  'Yang Wang': 161,
#  'Jiannong Cao': 161,
#  'Sushil Jajodia': 160,
#  'David Zhang': 160,
#  'Yong Zhang': 159,
#  'Yan Liu': 157,
#  'Kaushik Roy': 156,
#  'Kang G. Shin': 156,
#  'Jack Dongarra': 155,
#  'Qiang Yang': 155,
#  'Xin Liu': 155,
#  'Qian Zhang': 154,
#  'Luca Benini': 154,
#  'Jie Chen': 154,
#  'Gang Chen': 153,
#  'Xuemin Shen': 153,
#  'Hong Liu': 152,
#  'Azzedine Boukerche': 152,
#  'Yong Liu': 152,
#  'Hsinchun Chen': 151,
#  'Joseph Y. Halpern': 151,
#  'Wei Wu': 150,
#  'Tao Wang': 150,
#  'Yu Liu': 150,
#  'Thomas A. Henzinger': 149,
#  'Peng Zhang': 148,
#  'Ying Chen': 148,
#  'Yu Chen': 147,
#  'Saharon Shelah': 146,
#  'Helmut Krcmar': 145,
#  'Peng Liu': 145,
#  'Li Wang': 145,
#  'Qing Wang': 144,
#  'John Mylopoulos': 144,
#  'Nicholas R. Jennings': 143,
#  'Yue Wang': 143,
#  'Ling Liu': 142,
#  'Ping Li': 142,
#  'Karl Rihaczek': 140,
#  'Min Chen': 140,
#  'Shuicheng Yan': 140,
#  'Xi Chen': 140,
#  'Fatos Xhafa': 140,
#  'Ping Wang': 140,
#  'Azriel Rosenfeld': 139,
#  'Daniel Thalmann': 138,
#  'Christoph Meinel': 138,
#  'Feng Wang': 138,
#  'Wei Zhao': 138,
#  'Tao Zhang': 138,
#  'Francky Catthoor': 138,
#  'Hans-Peter Seidel': 137,
#  'Schahram Dustdar': 137,
#  'Peng Wang': 137,
#  'Didier Dubois': 136,
#  'Dacheng Tao': 136,
#  'Lei Guo': 136,
#  'Gang Li': 135,
#  'Gang Wang': 135,
#  'Victor C. M. Leung': 135,
#  'Hao Chen': 135,
#  'Feng Liu': 135,
#  'Josef Kittler': 134,
#  'Jun Sun': 134,
#  'Min Zhang': 134,
#  'Wei Xu': 134,
#  'Takeo Kanade': 133,
#  'Ugo Montanari': 133,
#  'Chun Chen': 133,
#  'Jie Li': 133,
#  'Guanrong Chen': 133,
#  'Fang Liu': 133,
#  'Rui Wang': 132,
#  'Michel Raynal': 132,
#  'Bin Zhang': 132,
#  'Yang Xiao': 132,
#  'Bart Preneel': 131,
#  'Erik D. Demaine': 131,
#  'Fei Wang': 131,
#  'Yong Yu': 131,
#  'Viktor K. Prasanna': 131,
#  'Bo Liu': 131,
#  'Gerhard Weikum': 130,
#  'Anil K. Jain': 130,
#  'Hong Wang': 130,
#  'Wenbo Wang': 130,
#  'Wei Sun': 129,
#  'Xi Zhang': 129,
#  'Wayne Luk': 128,
#  'Jie Liu': 128,
#  'Micha Sharir': 128,
#  'Ramesh Jain': 127,
#  'Moti Yung': 127,
#  'Tao Yang': 127,
#  'Xin Chen': 126,
#  'Vijay Kumar': 126,
#  'Hua Wang': 126,
#  'Ming Zhang': 124,
#  'Dong Wang': 124,
#  'Hartmut Ehrig': 123,
#  'Feng Li': 123,
#  'Vladik Kreinovich': 123,
#  'Ronald R. Yager': 123,
#  'Krishnendu Chakrabarty': 123,
#  'Horst Bunke': 122,
#  'Rachid Guerraoui': 122,
#  'Rajkumar Buyya': 122,
#  'Gonzalo Navarro': 122,
#  'Mateo Valero': 122,
#  'Jun Xu': 122,
#  'Nassir Navab': 121,
#  'K. J. Ray Liu': 121,
#  'Min Li': 121,
#  'Gang Feng': 121,
#  'Massoud Pedram': 121,
#  'Toshio Fukuda': 121,
#  'Klara Nahrstedt': 120,
#  'Barry Smyth': 120,
#  'Guy Pujolle': 120,
#  'Shojiro Nishio': 120,
#  'Robert L. Glass': 119,
#  'Michael Wooldridge': 119,
#  'Paul G. Spirakis': 119,
#  'Licheng Jiao': 119,
#  'Minglu Li': 119,
#  'Geoffrey Fox': 118,
#  'Munindar P. Singh': 118,
#  'Ming Liu': 118,
#  'Ben Shneiderman': 117,
#  'Eitan Altman': 117,
#  'Lothar Thiele': 117,
#  'Ning Zhong': 117,
#  'Qi Wang': 117,
#  'Yi Liu': 117,
#  'Wei Wei': 117,
#  'Ke Wang': 117,
#  'Dharma P. Agrawal': 117,
#  'Manfred Broy': 116,
#  'Matthias Jarke': 116,
#  'Arto Salomaa': 116,
#  'Meng Wang': 116,
#  'Norman C. Beaulieu': 116,
#  'Jie Wang': 116,
#  'Yang Zhang': 116,
#  'Willy Susilo': 115,
#  'Xindong Wu': 115,
#  'Zhongzhi Shi': 115,
#  'Sarit Kraus': 115,
#  'Wei Jiang': 115,
#  'Fan Zhang': 115,
#  'Peter Willett': 115,
#  'Hui Liu': 115,
#  'Hong Shen': 115,
#  'Christian S. Jensen': 114,
#  'Heinrich Niemann': 114,
#  'Katsumi Tanaka': 114,
#  'Tong Zhang': 114,
#  'C. Lee Giles': 114,
#  'Sungyoung Lee': 114,
#  'Michael R. Lyu': 114,
#  'Jan Treur': 114,
#  'Piet Demeester': 113,
#  'Xiaoou Tang': 113,
#  'Jin Li': 113,
#  'Rolf Drechsler': 113,
#  'Ke Xu': 113,
#  'Kian-Lee Tan': 112,
#  'Haizhou Li': 112,
#  'Stephan Olariu': 112,
#  'Wolfgang Nejdl': 112,
#  'Qi Tian': 112,
#  'Jian Chen': 112,
#  'Wei Yu': 112,
#  'Jun Ma': 112,
#  'Hong Chen': 111,
#  'Bernhard Thalheim': 111,
#  'Hsiao-Hwa Chen': 111,
#  'Georg Gottlob': 111,
#  'Rama Chellappa': 111,
#  'Hao Li': 111,
#  'Simon Parsons': 110,
#  'Li Liu': 110,
#  'Jie Xu': 110,
#  'Toby Walsh': 109,
#  'Sebastian Thrun': 109,
#  'Hector Garcia-Molina': 109,
#  'Peter G. Neumann': 109,
#  'Mohamed-Slim Alouini': 109,
#  'Liang Zhang': 109,
#  'Albert Y. Zomaya': 108,
#  'Peter J. Stuckey': 108,
#  'Christos H. Papadimitriou': 108,
#  'Yang Xu': 108,
#  'Chuang Lin': 108,
#  'David Peleg': 107,
#  'Xuelong Li': 107,
#  'V. S. Subrahmanian': 107,
#  'Reda Alhajj': 107,
#  'S. Muthukrishnan': 107,
#  'Bo Xu': 107,
#  'Steffen Staab': 106,
#  'Yi Li': 106,
#  'Jiajun Bu': 106,
#  'Thomas Ertl': 106,
#  'Wei Huang': 106,
#  'Dinesh Manocha': 105,
#  'W. Bruce Croft': 105,
#  'Qi Li': 105,
#  'Yong Li': 105,
#  'Bin Wu': 105,
#  'Oscar Castillo': 105,
#  'Hiroshi Ishiguro': 105,
#  'Michael T. Goodrich': 105,
#  'Tao Xie': 105,
#  'Huan Liu': 104,
#  'Yi Mu': 104,
#  'Yi Yang': 104,
#  'Xiaodong Zhang': 104,
#  'Hans-Peter Kriegel': 104,
#  'Jun Zhao': 104,
#  'Albrecht Schmidt': 104,
#  'Evangelos Kranakis': 104,
#  'Lei Li': 104,
#  'Bertrand Meyer': 103,
#  'Jon Crowcroft': 103,
#  'Changshui Zhang': 103,
#  'Peter Stone': 103,
#  'Masaru Kitsuregawa': 103,
#  'Patricia Melin': 103,
#  'Yi Pan': 103,
#  'Hideki Imai': 103,
#  'Yong Shi': 103,
#  'Hong Jiang': 103,
#  'Qi Zhang': 103,
#  'Wouter Joosen': 103,
#  'Tieniu Tan': 103,
#  'Giovanni De Micheli': 103,
#  'Bo Wang': 103,
#  'Satoshi Nakamura': 102,
#  'Zhaohui Wu': 102,
#  'Hong Yan': 102,
#  'Lei Xu': 102,
#  'Wei Lu': 102,
#  'Sudhakar M. Reddy': 102,
#  'H. V. Jagadish': 101,
#  'Mitsuru Ishizuka': 101,
#  'Chew Lim Tan': 101,
#  'Jiming Liu': 101,
#  'Zhen Liu': 101,
#  'Qian Wang': 101,
#  'Georgios B. Giannakis': 101,
#  'Elke A. Rundensteiner': 101,
#  'Xin Yao': 101,
#  'Jeffrey Xu Yu': 101,
#  'Dinggang Shen': 101,
#  'Masayuki Murata': 101,
#  'Hyunseung Choo': 101,
#  'David Eppstein': 100,
#  'Zheng Wang': 100,
#  'Vipin Kumar': 100,
#  'Lionel M. Ni': 100,
#  'Jin Wang': 100,
#  'Gerhard J. Woeginger': 100,
#  'Bing Liu': 100,
#  'John M. Carroll': 99,
#  'Edward A. Fox': 99,
#  'Wolfgang Rosenstiel': 99,
#  'Alex Waibel': 99,
#  'Oscar H. Ibarra': 99,
#  'Horst Bischof': 99,
#  'Stefano Ceri': 99,
#  'Jason Cong': 99,
#  'Lei He': 99,
#  'Manfred Tscheligi': 99,
#  'Qiang Wang': 99,
#  'Erol Gelenbe': 98,
#  'Andrew Zisserman': 98,
#  'Calton Pu': 98,
#  'Masahiro Fujita': 98,
#  'Frank Leymann': 98,
#  'Tharam S. Dillon': 98,
#  'Yunhao Liu': 98,
#  'Alan F. Smeaton': 98,
#  'Oscar C. Au': 98,
#  'Chao Zhang': 98,
#  'Peter J. Denning': 97,
#  'Min Wu': 97,
#  'Kurt Mehlhorn': 97,
#  'Athanasios V. Vasilakos': 97,
#  'Insup Lee': 97,
#  'Franco Zambonelli': 97,
#  'Jian Pei': 97,
#  'Di Wu': 97,
#  'Shlomi Dolev': 96,
#  'Ning Wang': 96,
#  'Feng Wu': 96,
#  'Gerhard Fettweis': 96,
#  'Bernd Girod': 96,
#  'Shusaku Tsumoto': 96,
#  'Feng Chen': 96,
#  'Ning Xi': 96,
#  'Edmond Bianco': 95,
#  'Dhabaleswar K. Panda': 95,
#  'Gunter Saake': 95,
#  'Kishor S. Trivedi': 95,
#  'Bernhard Steffen': 95,
#  'Chang Wen Chen': 95,
#  'Wolfram Burgard': 95,
#  'Milind Tambe': 95,
#  'Jian Huang': 95,
#  'Dirk Fox': 94,
#  'Divesh Srivastava': 94,
#  'Yannis Manolopoulos': 94,
#  'David Taniar': 94,
#  'Nan Zhang': 94,
#  'Scott Shenker': 94,
#  'Kazuyuki Aihara': 94,
#  'Ming Chen': 94,
#  'Liang Chen': 94,
#  'Taghi M. Khoshgoftaar': 94,
#  'Tzung-Pei Hong': 94,
#  'Qiang Li': 94,
#  'Long Wang': 94,
#  'Peng Shi': 94,
#  'Hiroshi G. Okuno': 94,
#  'Ling Wang': 94,
#  'Manfred Glesner': 93,
#  'Dong Xu': 93,
#  'Manuela M. Veloso': 93,
#  'Laurence T. Yang': 93,
#  'David Blaauw': 93,
#  'Gerd Hirzinger': 93,
#  'Hong Zhu': 93,
#  'Lei Liu': 93,
#  'Fan Yang': 93,
#  'Divyakant Agrawal': 93,
#  'Yuan Li': 93,
#  'Choong Seon Hong': 93,
#  'Cheng Wang': 93,
#  'Prosenjit Bose': 92,
#  'Ernesto Damiani': 92,
#  'Sheng Li': 92,
#  'Elizabeth Chang': 92,
#  'Ian H. Witten': 92,
#  'Liang Wang': 92,
#  'Jiangchuan Liu': 92,
#  'Hanqing Lu': 92,
#  'Abhijit Chatterjee': 92,
#  'Hideharu Amano': 92,
#  'Hans L. Bodlaender': 91,
#  'Andrew B. Kahng': 91,
#  'Bernard De Baets': 91,
#  'Michael I. Jordan': 91,
#  'Carles Sierra': 91,
#  'Chen Wang': 91,
#  'Hao Wu': 91,
#  'Min Wang': 91,
#  'Jian Wu': 91,
#  'Karl Aberer': 91,
#  'Jean Vanderdonckt': 91,
#  'Yishay Mansour': 91,
#  'Ian F. Akyildiz': 91,
#  'Jia Liu': 91,
#  'Wei-Ying Ma': 91,
#  'Yang Xiang': 91,
#  'Pankaj K. Agarwal': 90,
#  'Feng Zhao': 90,
#  'Josef Pieprzyk': 90,
#  'Alberto Del Bimbo': 90,
#  'Kouichi Sakurai': 90,
#  'Boi Faltings': 90,
#  'Enrique Alba': 90,
#  'Qiang Wu': 90,
#  'Li Yang': 90,
#  'Bin Zhou': 90,
#  'Hong Mei': 90,
#  'Irith Pomeranz': 90,
#  'Xue Liu': 90,
#  'Li Xu': 89,
#  'Xiaofang Zhou': 89,
#  'Mark Harman': 89,
#  'Sanjay Jain': 89,
#  'Gang Liu': 89,
#  'Miodrag Potkonjak': 89,
#  'Jing Huang': 89,
#  'Ee-Peng Lim': 89,
#  'Chen Chen': 89,
#  'Takahiro Hara': 89,
#  'Kai Wang': 89,
#  'Ian Horrocks': 88,
#  'Leonidas J. Guibas': 88,
#  'Ying Wu': 88,
#  'Hanan Samet': 88,
#  'Umeshwar Dayal': 88,
#  'Marianne Winslett': 88,
#  'Jing Chen': 88,
#  'Dan Roth': 88,
#  'Yuan Yuan': 88,
#  'Tsuhan Chen': 88,
#  'Juan M. Corchado': 88,
#  'Zheng Li': 88,
#  'Zhenfu Cao': 88,
#  'Ge Yu': 88,
#  'Gustavo Alonso': 87,
#  'Shipeng Li': 87,
#  'Maarten de Rijke': 87,
#  'Moshe Tennenholtz': 87,
#  'Luc De Raedt': 87,
#  'Raghu Ramakrishnan': 87,
#  'Roberto Cipolla': 87,
#  'Volker Gruhn': 87,
#  'Narendra Ahuja': 87,
#  'Amir Pnueli': 87,
#  'Hussein T. Mouftah': 87,
#  'Kotagiri Ramamohanarao': 87,
#  'Jian Ma': 87,
#  'Andrzej Cichocki': 87,
#  'Floriana Esposito': 87,
#  'Chengqi Zhang': 87,
#  'Atsuo Takanishi': 87,
#  'Satoshi Goto': 87,
#  'Jie Zhou': 87,
#  'Mihaela van der Schaar': 87,
#  'Xi Li': 87,
#  'Khaled Ben Letaief': 87,
#  'Yuguang Fang': 87,
#  'Lin Zhang': 87,
#  'Gerhard Rigoll': 87,
#  'Rajeev Alur': 86,
#  'Fei Liu': 86,
#  'Hanif D. Sherali': 86,
#  'Andrzej Skowron': 86,
#  'Toyoaki Nishida': 86,
#  'Tat-Seng Chua': 86,
#  'Sheng Chen': 86,
#  'Larry S. Davis': 86,
#  'Michele Zorzi': 86,
#  'Ling Chen': 86,
#  'Lei Shi': 86,
#  'Lin Chen': 86,
#  'Panos M. Pardalos': 86,
#  'Liang Zhao': 86,
#  'Mohammad S. Obaidat': 86,
#  'Thomas Eiter': 86,
#  'Yi-Bing Lin': 86,
#  'Qiang Liu': 86,
#  'Jie Tang': 86,
#  'Li Deng': 86,
#  'Aidong Zhang': 86,
#  'Xiang-Gen Xia': 85,
#  'Rajiv Gupta': 85,
#  'T. D. Wilson': 85,
#  'Zhi-Hua Zhou': 85,
#  'Jun Wu': 85,
#  'Frank Dignum': 85,
#  'Toru Ishida': 85,
#  'Mehdi Dehghan': 85,
#  'Minoru Asada': 85,
#  'Salem Benferhat': 85,
#  'Gagan Agrawal': 85,
#  'Jian Liu': 85,
#  'Jin Zhang': 85,
#  'Shrikanth Narayanan': 85,
#  'Emilio Luque': 85,
#  'Kurt Rothermel': 85,
#  'Jun Luo': 85,
#  'Tao Liu': 85,
#  'Jianzhong Li': 85,
#  'Ming-Syan Chen': 85,
#  'Ahmad-Reza Sadeghi': 85,
#  'Lihua Xie': 85,
#  'Wei Zhou': 85,
#  'Gilbert Laporte': 84,
#  'Nicholas Ayache': 84,
#  'Rafail Ostrovsky': 84,
#  'David Maier': 84,
#  'Serge Abiteboul': 84,
#  'Robert Schober': 84,
#  'Majid Sarrafzadeh': 84,
#  'Daniela Rus': 84,
#  'Weijia Jia': 84,
#  'Kwan-Liu Ma': 84,
#  'Katsushi Ikeuchi': 84,
#  'Amr El Abbadi': 84,
#  'Jun Chen': 84,
#  'Ning Li': 84,
#  'Carlos A. Coello Coello': 84,
#  'Michael Stonebraker': 83,
#  'Timothy K. Shih': 83,
#  'Diego Calvanese': 83,
#  'Steve Benford': 83,
#  'Nachum Dershowitz': 83,
#  'Yueh-Min Huang': 83,
#  'Derick Wood': 83,
#  'Beng Chin Ooi': 83,
#  'Thomas Seidl': 83,
#  'Yin Zhang': 83,
#  'Naohiro Ishii': 83,
#  'Wayne Wolf': 83,
#  'Carl Gutwin': 83,
#  'Saul Greenberg': 83,
#  'Kalyanmoy Deb': 83,
#  'Josep Domingo-Ferrer': 83,
#  'Douglas C. Schmidt': 83,
#  'David J. Evans': 83,
#  'Hui Chen': 83,
#  'Wolfgang Lehner': 83,
#  'Nicola Santoro': 83,
#  'Donato Malerba': 83,
#  'Hongbin Zha': 83,
#  'Daphne Koller': 83,
#  'Aoying Zhou': 82,
#  'Pierangela Samarati': 82,
#  'Andrea Omicini': 82,
#  'Udo Hahn': 82,
#  'Yuri Gurevich': 82,
#  'Manfred Reichert': 82,
#  'Dov M. Gabbay': 82,
#  'Carlo Ghezzi': 82,
#  'Rong Jin': 82,
#  'Lei Yang': 82,
#  'Eric Horvitz': 82,
#  'Minyi Guo': 82,
#  'Brad A. Myers': 82,
#  'Bin Yang': 82,
#  'Dacheng Yang': 82,
#  'Rahim Tafazolli': 82,
#  'Bill Hancock': 81,
#  'Filip De Turck': 81,
#  'Ravi Kumar': 81,
#  'Bernhard Rumpe': 81,
#  'Sridha Sridharan': 81,
#  'Ning Zhang': 81,
#  'Martin Buss': 81,
#  'Don Towsley': 81,
#  'Karsten Schwan': 81,
#  'Jacob A. Abraham': 81,
#  'Bernd Becker': 81,
#  'Xiaotie Deng': 81,
#  'Marc Moonen': 81,
#  'Yun Yang': 81,
#  'Lu Zhang': 81,
#  'Patrick Valduriez': 81,
#  'Chang Liu': 81,
#  'Sahin Albayrak': 81,
#  'D. J. Evans': 81,
#  'Gene Tsudik': 81,
#  'Inkyu Lee': 81,
#  'Hisao Ishibuchi': 81,
#  'Xianlong Hong': 81,
#  'Francisco Herrera': 81,
#  'Yong He': 80,
#  'Gheorghe Paun': 80,
#  'Svetha Venkatesh': 80,
#  'Yves Robert': 80,
#  'Hamid R. Arabnia': 80,
#  'Fausto Giunchiglia': 80,
#  'Zakaria Maamar': 80,
#  'Jue Wang': 80,
#  'Bing Li': 80,
#  'Paolo Dario': 80,
#  'Mary Beth Rosson': 80,
#  'Ioannis Pitas': 80,
#  'Xin Jin': 80,
#  'Marek Karpinski': 80,
#  'Wei Hu': 80,
#  'Kiyohiro Shikano': 80,
#  'Tomoya Enokido': 80,
#  'Christos Bouras': 80,
#  'Johann Bizer': 79,
#  'James Noble': 79,
#  'Roland Siegwart': 79,
#  'Mubarak Shah': 79,
#  'Aggelos K. Katsaggelos': 79,
#  'Vijay Varadharajan': 79,
#  'Jiebo Luo': 79,
#  'Catholijn M. Jonker': 79,
#  'Kaoru Hirota': 79,
#  'Andreas Uhl': 79,
#  'Yang Chen': 79,
#  'Yan Huang': 79,
#  'Fumiyuki Adachi': 79,
#  'Xiaobo Zhou': 79,
#  'Hongxun Yao': 79,
#  'Jianping Fan': 79,
#  'Ching Y. Suen': 79,
#  'Mengjie Zhang': 79,
#  'Kalle Lyytinen': 79,
#  'Arjan Durresi': 79,
#  'Jianping Wu': 79,
#  'Bin Ma': 79,
#  'C.-C. Jay Kuo': 79,
#  'Zhi Ding': 79,
#  'Dennis Sylvester': 79,
#  'Chao-Tung Yang': 79,
#  'Maurice Bruynooghe': 78,
#  'Pascal Van Hentenryck': 78,
#  'Ying Xu': 78,
#  'Yi Sun': 78,
#  'Giancarlo Mauri': 78,
#  'Guillermo Sapiro': 78,
#  'Oded Goldreich': 78,
#  'Zhe Wang': 78,
#  'Ivan Stojmenovic': 78,
#  'Henning Schulzrinne': 78,
#  'Geyong Min': 78,
#  'Daniel A. Keim': 78,
#  'Baowen Xu': 78,
#  'Gregor Engels': 78,
#  'Zhen Zhang': 78,
#  'Shinichi Honiden': 78,
#  'Bo Chen': 78,
#  'Jun Guo': 78,
#  'Lin Li': 78,
#  'Weiming Shen': 78,
#  'Chin-Hui Lee': 78,
#  'Xiang-Yang Li': 78,
#  'Diane J. Cook': 78,
#  'Prasant Mohapatra': 78,
#  'Hiroshi Nagamochi': 78,
#  'Krithi Ramamritham': 78,
#  'Zhu Han': 78,
#  'Ming Yang': 77,
#  'Bernd Hamann': 77,
#  'Hong Li': 77,
#  'Frank Stephan': 77,
#  'Dan Suciu': 77,
#  'Takeo Igarashi': 77,
#  'Yoshua Bengio': 77,
#  'Adrian David Cheok': 77,
#  'Abdul Sattar': 77,
#  'Won Kim': 77,
#  'Fedor V. Fomin': 77,
#  'Baochun Li': 77,
#  'Giuseppe De Giacomo': 77,
#  'Luigi Carro': 77,
#  'Robert M. Haralick': 77,
#  'Nicu Sebe': 77,
#  'Daniel Rueckert': 77,
#  'Jun Zhu': 77,
#  'Hee Yong Youn': 77,
#  'Tao Chen': 77,
#  'Patrick Gallinari': 77,
#  'Lin Wang': 77,
#  'Keikichi Hirose': 77,
#  'Thomas Fahringer': 77,
#  'Qiang Ji': 77,
#  'Zheng Chen': 77,
#  'Xian-Sheng Hua': 76,
#  'Nadia Magnenat-Thalmann': 76,
#  'Jack Snoeyink': 76,
#  'Weiming Hu': 76,
#  'Rakesh Agrawal': 76,
#  'Michael J. Carey': 76,
#  'Ramesh Raskar': 76,
#  'Maurice Herlihy': 76,
#  'Zidong Wang': 76,
#  'Guido Governatori': 76,
#  'Amit P. Sheth': 76,
#  'David E. Goldberg': 76,
#  'Leandros Tassiulas': 76,
#  'Wang-Chien Lee': 76,
#  'Fillia Makedon': 76,
#  'Michael Kaufmann': 76,
#  'Maxime Crochemore': 76,
#  'Jianer Chen': 76,
#  'Sung-Bae Cho': 76,
#  'Moncef Gabbouj': 76,
#  'Yong Chen': 76,
#  'Norihiro Hagita': 76,
#  'Howard Jay Siegel': 76,
#  'Ophir Frieder': 76,
#  'Tok Wang Ling': 76,
#  'C. Pandu Rangan': 76,
#  'Bo Hu': 76,
#  'Wei Yang': 76,
#  'Victor O. K. Li': 76,
#  'Tatsuo Nakajima': 76,
#  'Fabrizio Lombardi': 76,
#  'Raouf Boutaba': 75,
#  'Dong Li': 75,
#  'Venu Govindaraju': 75,
#  'Michael Luck': 75,
#  'Mounia Lalmas': 75,
#  'Gabriel Ciobanu': 75,
#  'Katia Sycara': 75,
#  'Guoliang Xue': 75,
#  'Joachim Hornegger': 75,
#  'Guang-Zhong Yang': 75,
#  'Michael Unser': 75,
#  'Pierre Hansen': 75,
#  'Yiyu Yao': 75,
#  'Michael Beetz': 75,
#  'Jennifer Widom': 75,
#  'Xia Li': 75,
#  'Tzi-cker Chiueh': 75,
#  'Min Xu': 75,
#  'Jong Hyuk Park': 75,
#  'Hai Lin': 75,
#  'Enrico Motta': 75,
#  'Zhen Li': 75,
#  'Niraj K. Jha': 75,
#  'Wei Song': 75,
#  'Chao Li': 75,
#  'Yao-Wen Chang': 75,
#  'Yang Song': 75,
#  'Hossam S. Hassanein': 75,
#  'Franz Baader': 74,
#  'Mark Billinghurst': 74,
#  'Richard T. Snodgrass': 74,
#  'Loet Leydesdorff': 74,
#  'Torsten Schaub': 74,
#  'Jie Lu': 74,
#  'John M. Cioffi': 74,
#  'Jia Wang': 74,
#  'Avi Wigderson': 74,
#  'Xiaoyi Jiang': 74,
#  'Reihaneh Safavi-Naini': 74,
#  'Stan Z. Li': 74,
#  'Kai Li': 74,
#  'Lakhmi C. Jain': 74,
#  'Roberto Tamassia': 74,
#  'Wilfried Philips': 74,
#  'Yuji Matsumoto': 74,
#  'Dong Hoon Lee': 74,
#  'Shih-Fu Chang': 74,
#  'Kannan Ramchandran': 74,
#  'wang': 74,
#  'Bir Bhanu': 74,
#  'Marcin Paprzycki': 74,
#  'Qiang Zhang': 74,
#  'Chin-Teng Lin': 74,
#  'Biswanath Mukherjee': 74,
#  'Han-Chieh Chao': 74,
#  'Xin Yang': 74,
#  'li': 74,
#  'Yangsheng Xu': 74,
#  'Jun He': 74,
#  'Jing Yang': 74,
#  'Keshab K. Parhi': 73,
#  'Hiroshi Ishii': 73,
#  'Mike Thelwall': 73,
#  'Grigoris Antoniou': 73,
#  'Dieter Rautenbach': 73,
#  'Leif Kobbelt': 73,
#  'Reinhard Klette': 73,
#  'Pascal Bouvry': 73,
#  'Michael A. Henning': 73,
#  'Joseph S. B. Mitchell': 73,
#  'Mohamed S. Kamel': 73,
#  'Dan Boneh': 73,
#  'Mihalis Yannakakis': 73,
#  'Peter Brusilovsky': 73,
#  'Weimin Zheng': 73,
#  'Uwe Aickelin': 73,
#  'Giancarlo Succi': 73,
#  'Jeffrey Scott Vitter': 73,
#  'Bernd Freisleben': 73,
#  'Hiroshi Harada': 73,
#  'Jinde Cao': 73,
#  'Jun Zhou': 73,
#  'Andrzej Pelc': 73,
#  'Lin Liu': 73,
#  'vu': 73,
#  'Lin Yang': 73,
#  'Ting Liu': 73,
#  'Jun Hu': 73,
#  'Dan Wang': 73,
#  'Ke Chen': 73,
#  'Risto Miikkulainen': 72,
#  'Justin Zobel': 72,
#  'James H. Anderson': 72,
#  'Anton Nijholt': 72,
#  'Tuomas Sandholm': 72,
#  'Haixun Wang': 72,
#  'Alexander Schill': 72,
#  'Swagatam Das': 72,
#  'Alistair Moffat': 72,
#  'Sandip Sen': 72,
#  'Iadh Ounis': 72,
#  'Alex Acero': 72,
#  'Lang Tong': 72,
#  'Hsin-Hsi Chen': 72,
#  'Sanguthevar Rajasekaran': 72,
#  'Jian Xu': 72,
#  'Debin Zhao': 72,
#  'Yang Yu': 72,
#  'Oscar Pastor': 72,
#  'Feng Bao': 72,
#  'Chen Li': 72,
#  'Xiaolin Wu': 72,
#  'Robert J. Kauffman': 72,
#  'Norio Shiratori': 72,
#  'J. J. Garcia-Luna-Aceves': 72,
#  'Haim Kaplan': 71,
#  'Emilio Corchado': 71,
#  'Heung-Yeung Shum': 71,
#  'Xuding Zhu': 71,
#  'Radko Mesiar': 71,
#  'Moni Naor': 71,
#  'Michael Mitzenmacher': 71,
#  'Weihua Zhuang': 71,
#  'Geoffrey E. Hinton': 71,
#  'Rodrigo C. de Lamare': 71,
#  'Makoto Ikeda': 71,
#  'Prabhakar Raghavan': 71,
#  'Tho Le-Ngoc': 71,
#  'Jeffrey D. Ullman': 71,
#  'Jieping Ye': 71,
#  'Huijun Gao': 71,
#  'Dieter Fensel': 71,
#  'Xiaohua Hu': 71,
#  'Tanja Schultz': 71,
#  'Carlo Zaniolo': 71,
#  'Yao Wang': 71,
#  'Guido Boella': 71,
#  'Ed Dawson': 71,
#  'Charles J. Colbourn': 71,
#  'Yu Sun': 71,
#  'P. Sadayappan': 71,
#  'William H. Sanders': 71,
#  'Pramod K. Varshney': 71,
#  'Ting Wang': 71,
#  'Hitoshi Isahara': 71,
#  'Jeffrey G. Andrews': 71,
#  'Francis C. M. Lau': 71,
#  'Lance Fortnow': 70,
#  'Reinhard Wilhelm': 70,
#  'Enrico Pontelli': 70,
#  'Dorothea Wagner': 70,
#  'Stefan Langerman': 70,
#  'Pan Jeng-Shyang': 70,
#  'Ron Kikinis': 70,
#  'Xiaofeng Wang': 70,
#  'Orna Kupferman': 70,
#  'Joachim Weickert': 70,
#  'Xiaoqing Ding': 70,
#  'Jonathan Schaeffer': 70,
#  'Hong-Jiang Zhang': 70,
#  'Andrew Lim': 70,
#  'Riccardo Poli': 70,
#  'Zsolt Tuza': 70,
#  'Michael Weber': 70,
#  'Hua Li': 70,
#  'Jon W. Mark': 70,
#  'Mathias Weske': 70,
#  'Edward R. Dougherty': 70,
#  'Peter Widmayer': 70,
#  'Andreas Zell': 70,
#  'Xilin Chen': 70,
#  'Chung-Kuan Cheng': 70,
#  'Lawrence Carin': 70,
#  'Xinbing Wang': 70,
#  'Fei Li': 70,
#  'Ye Li': 70,
#  'Shyi-Ming Chen': 70,
#  'Yoshitaka Shibata': 70,
#  'Hao Liu': 70,
#  'Felix Naumann': 69,
#  'David Alan Grier': 69,
#  'David Harel': 69,
#  'Bart Jacobs': 69,
#  'John R. Smith': 69,
#  'John A. Stankovic': 69,
#  'Henrik I. Christensen': 69,
#  'Jan Marco Leimeister': 69,
#  'Nanning Zheng': 69,
#  'Omer F. Rana': 69,
#  'Bin Xu': 69,
#  'Maurizio Lenzerini': 69,
#  'Herbert Edelsbrunner': 69,
#  'Pascal Fua': 69,
#  'John C. Mitchell': 69,
#  'Dan Keun Sung': 69,
#  'Joemon M. Jose': 69,
#  'Kotaro Hirasawa': 69,
#  'Mikhail J. Atallah': 69,
#  'Lutz Volkmann': 69,
#  'Edmund M. Clarke': 69,
#  'Alan M. Frieze': 69,
#  'Dan Feng': 69,
#  'Marc Pollefeys': 69,
#  'Shrikanth S. Narayanan': 69,
#  'Yu-Chee Tseng': 69,
#  'Klaus Jansen': 69,
#  'Yao Zhao': 69,
#  'Yanchun Zhang': 69,
#  'Jiang Li': 69,
#  'Chunming Qiao': 69,
#  'Jun Wei': 69,
#  'Robert H. Deng': 69,
#  'Ling Guan': 69,
#  'Marian Bubak': 69,
#  'Jing Xu': 69,
#  'Guihai Chen': 69,
#  'Zhiwen Yu': 69,
#  'Alois Potton': 68,
#  'Peter Mertens': 68,
#  'Daniel S. Weld': 68,
#  'Pascal Hitzler': 68,
#  'Zhengyou Zhang': 68,
#  'Oscar Nierstrasz': 68,
#  'Lior Rokach': 68,
#  'William W. Cohen': 68,
#  'Marijn Janssen': 68,
#  'Pierre Fraigniaud': 68,
#  'Martial Hebert': 68,
#  'Fabio Casati': 68,
#  ...}

# %%
type(top_n_authors)
# Out:
# dict

# %%
def get_authors_list(x):
    authors = []
    if not isinstance(x, list):
        return authors
    for author in x:
        if 'name' in author and author['name'] in top_n_authors:
            authors.append(author['name'])
    return authors

df['authors_list'] = df.authors.apply(get_authors_list)

# %%
df.head()
# Out:
#                         _id  \
# 0  53e99784b7602d9701f3e3f5
# 1  53e99784b7602d9701f3e133
# 2  53e99784b7602d9701f3e151
# 3  53e99784b7602d9701f3e15d
# 4  53e99784b7602d9701f3e161
#
#                                                title  \
# 0                                              3GIO.
# 1  The relationship between canopy parameters and...
# 2  A solution to the problem of touching and brok...
# 3  Timing yield estimation using statistical stat...
# 4                                               360°
#
#                                                venue    year  \
# 0                                        {'type': 0}  2011.0
# 1  {'_id': '53a7297d20f7420be8bd4ae7', 'name_d': ...  2011.0
# 2  {'_id': '53a72a4920f7420be8bfa51b', 'name_d': ...  1993.0
# 3  {'_id': '53a72e2020f7420be8c80142', 'name_d': ...  2005.0
# 4  {'_id': '5390a74a20f70186a0e8b40b', 'raw': 'AC...  2009.0
#
#                                             keywords  n_citation lang  \
# 0                                                 []         0.0   en
# 1  [canopy parameters, canopy spectrum, different...         0.0   en
# 2  [handwriting recognition, prototypes, image se...        17.0   en
# 3  [sequential circuits, statistical distribution...        28.0   en
# 4  [global high technology, daily short-distance ...         NaN   en
#
#                                              authors  \
# 0                                                NaN
# 1  [{'_id': '53f45728dabfaec09f209538', 'name': '...
# 2  [{'_id': '53f46797dabfaeb22f542630', 'name': '...
# 3  [{'_id': '53f43b03dabfaedce555bf2a', 'name': '...
# 4  [{'_id': '53f46946dabfaec09f24b4ed', 'name': '...
#
#                                                  fos page_start  ... issue  \
# 0                                                NaN        NaN  ...   NaN
# 1  [Agronomy, Moisture, Hydrology, Environmental ...       1930  ...  null
# 2  [Intelligent character recognition, Pattern re...        602  ...
# 3  [Delay calculation, Timing failure, Monte Carl...       2461  ...
# 4                                                NaN         39  ...
#
#   issn           isbn                          doi  \
# 0  NaN            NaN                          NaN
# 1                      10.1109/IGARSS.2011.6049503
# 2                        10.1109/ICDAR.1993.395663
# 3       0-7803-8834-8   10.1109/ISCAS.2005.1465124
# 4                          10.1145/1665137.1665166
#
#                                                  pdf  \
# 0                                                NaN
# 1                                               None
# 2                                               None
# 3  //static.aminer.org/pdf/PDF/000/423/329/timing...
# 4                                                NaN
#
#                                                  url  \
# 0                                                NaN
# 1    [http://dx.doi.org/10.1109/IGARSS.2011.6049503]
# 2      [http://dx.doi.org/10.1109/ICDAR.1993.395663]
# 3  [http://dx.doi.org/10.1109/ISCAS.2005.1465124,...
# 4                                                NaN
#
#                                             abstract  \
# 0                                                NaN
# 1  Drought is the first place in all the natural ...
# 2
# 3  As process variations become a significant pro...
# 4  360° represents the concerns that are addresse...
#
#                                           references chunk_idx  \
# 0                                                NaN         0
# 1                                                NaN         0
# 2  [53e99cf5b7602d97025ace63, 557e8a7a6fee0fe990c...         0
# 3  [53e9a8a9b7602d97031f6bb9, 599c7b6b601a182cd27...         0
# 4                                                NaN         0
#
#                   authors_list
# 0                           []
# 1                     [Yun Xu]
# 2                           []
# 3  [Chris C. N. Chu, Hai Zhou]
# 4                           []
#
# [5 rows x 22 columns]

# %%
# %%time
te = TransactionEncoder()
te_ary = te.fit(df['authors_list']).transform(df['authors_list'])
# Out:
# CPU times: user 1.2 s, sys: 770 ms, total: 1.97 s
# Wall time: 2.07 s

# %%
te_ary
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df_te = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df_te.head()
# Out:
#     Arvind   CACM Staff   Computer Staff   IEEE Expert staff  \
# 0    False        False            False               False
# 1    False        False            False               False
# 2    False        False            False               False
# 3    False        False            False               False
# 4    False        False            False               False
#
#     IEEE Software Staff   Kinshuk   Luqi   Staff   Ubiquity staff  A Min Tjoa  \
# 0                 False     False  False   False            False       False
# 1                 False     False  False   False            False       False
# 2                 False     False  False   False            False       False
# 3                 False     False  False   False            False       False
# 4                 False     False  False   False            False       False
#
#    ...   wang    wei     wu     xu   yang     yu  zhang   zhao   zhou    zhu
# 0  ...  False  False  False  False  False  False  False  False  False  False
# 1  ...  False  False  False  False  False  False  False  False  False  False
# 2  ...  False  False  False  False  False  False  False  False  False  False
# 3  ...  False  False  False  False  False  False  False  False  False  False
# 4  ...  False  False  False  False  False  False  False  False  False  False
#
# [5 rows x 30000 columns]

# %%
# %%time
res = fpgrowth(df_te, min_support=1e-30, use_colnames=True, max_len=2)
# Out:
# CPU times: user 35.7 s, sys: 16.3 s, total: 52 s
# Wall time: 1min 2s

# %%
res_rules = association_rules(res, metric="lift", min_threshold=1)
res_rules
# Out:
#             antecedents      consequents  antecedent support  \
# 0       (Guoliang Chen)         (Yun Xu)            0.000035
# 1              (Yun Xu)  (Guoliang Chen)            0.000019
# 2               (Di Wu)         (Yun Xu)            0.000097
# 3              (Yun Xu)          (Di Wu)            0.000019
# 4            (Yi Shang)         (Yun Xu)            0.000032
# ...                 ...              ...                 ...
# 359879      (Kai Zhang)     (Weijun Liu)            0.000061
# 359880    (Jinhua Wang)     (Weijun Liu)            0.000013
# 359881     (Weijun Liu)    (Jinhua Wang)            0.000013
# 359882        (Wei Jin)     (Weijun Liu)            0.000029
# 359883     (Weijun Liu)        (Wei Jin)            0.000013
#
#         consequent support   support  confidence         lift      leverage  \
# 0                 0.000019  0.000003    0.085714  4511.278195  2.999335e-06
# 1                 0.000035  0.000003    0.157895  4511.278195  2.999335e-06
# 2                 0.000019  0.000001    0.010309   542.593597  9.981570e-07
# 3                 0.000097  0.000001    0.052632   542.593597  9.981570e-07
# 4                 0.000019  0.000002    0.062500  3289.473684  1.999392e-06
# ...                    ...       ...         ...          ...           ...
# 359879            0.000013  0.000001    0.016393  1261.034048  9.992070e-07
# 359880            0.000013  0.000001    0.076923  5917.159763  9.998310e-07
# 359881            0.000013  0.000001    0.076923  5917.159763  9.998310e-07
# 359882            0.000013  0.000001    0.034483  2652.519894  9.996230e-07
# 359883            0.000029  0.000001    0.076923  2652.519894  9.996230e-07
#
#         conviction
# 0         1.093729
# 1         1.187458
# 2         1.010397
# 3         1.055453
# 4         1.066646
# ...            ...
# 359879    1.016653
# 359880    1.083319
# 359881    1.083319
# 359882    1.035701
# 359883    1.083302
#
# [359884 rows x 9 columns]

# %%
res_rules[res_rules.antecedents.eq({'Guoliang Chen'})]
# Out:
#             antecedents           consequents  antecedent support  \
# 0       (Guoliang Chen)              (Yun Xu)            0.000035
# 20764   (Guoliang Chen)          (Yunji Chen)            0.000035
# 73285   (Guoliang Chen)        (Huaping Chen)            0.000035
# 149971  (Guoliang Chen)     (Darrell Whitley)            0.000035
# 158652  (Guoliang Chen)            (Qiang Lu)            0.000035
# 213300  (Guoliang Chen)        (Tianshi Chen)            0.000035
# 213439  (Guoliang Chen)          (Yixin Chen)            0.000035
# 213441  (Guoliang Chen)      (Yongsheng Ding)            0.000035
# 213443  (Guoliang Chen)           (Jing Wang)            0.000035
# 213444  (Guoliang Chen)            (Rui Wang)            0.000035
# 213447  (Guoliang Chen)      (Weixiong Zhang)            0.000035
# 213449  (Guoliang Chen)             (Xin Yao)            0.000035
# 213451  (Guoliang Chen)   (Hussein A. Abbass)            0.000035
# 213453  (Guoliang Chen)         (Hitoshi Iba)            0.000035
# 213455  (Guoliang Chen)         (Xiaodong Li)            0.000035
# 213456  (Guoliang Chen)              (Tao Li)            0.000035
# 213459  (Guoliang Chen)         (Weifa Liang)            0.000035
# 213460  (Guoliang Chen)  (Khaled Ben Letaief)            0.000035
# 213463  (Guoliang Chen)          (Hong Zhang)            0.000035
# 213465  (Guoliang Chen)            (Xin Chen)            0.000035
# 224013  (Guoliang Chen)              (Qi Guo)            0.000035
# 235205  (Guoliang Chen)            (Weiwu Hu)            0.000035
# 238930  (Guoliang Chen)              (Yu Zhu)            0.000035
# 250036  (Guoliang Chen)       (Huanhuan Chen)            0.000035
# 267367  (Guoliang Chen)            (Jing Cai)            0.000035
# 276505  (Guoliang Chen)             (Ke Tang)            0.000035
# 296333  (Guoliang Chen)             (Tao Luo)            0.000035
# 301659  (Guoliang Chen)          (Yinlong Xu)            0.000035
# 306823  (Guoliang Chen)     (Erik D. Goodman)            0.000035
# 320067  (Guoliang Chen)       (Shu-Heng Chen)            0.000035
# 324956  (Guoliang Chen)        (Xinhan Huang)            0.000035
# 347094  (Guoliang Chen)      (Xianchao Zhang)            0.000035
# 348427  (Guoliang Chen)       (Yunquan Zhang)            0.000035
# 349068  (Guoliang Chen)           (Xufa Wang)            0.000035
#
#         consequent support   support  confidence         lift      leverage  \
# 0                 0.000019  0.000003    0.085714  4511.278195  2.999335e-06
# 20764             0.000021  0.000001    0.028571  1360.544218  9.992650e-07
# 73285             0.000020  0.000001    0.028571  1428.571429  9.993000e-07
# 149971            0.000031  0.000001    0.028571   921.658986  9.989150e-07
# 158652            0.000019  0.000002    0.057143  3007.518797  1.999335e-06
# 213300            0.000027  0.000002    0.057143  2116.402116  1.999055e-06
# 213439            0.000057  0.000002    0.057143  1002.506266  1.998005e-06
# 213441            0.000037  0.000001    0.028571   772.200772  9.987050e-07
# 213443            0.000232  0.000001    0.028571   123.152709  9.918800e-07
# 213444            0.000131  0.000001    0.028571   218.102508  9.954150e-07
# 213447            0.000039  0.000001    0.028571   732.600733  9.986350e-07
# 213449            0.000101  0.000002    0.057143   565.770863  1.996465e-06
# 213451            0.000046  0.000001    0.028571   621.118012  9.983900e-07
# 213453            0.000060  0.000001    0.028571   476.190476  9.979000e-07
# 213455            0.000062  0.000001    0.028571   460.829493  9.978300e-07
# 213456            0.000224  0.000001    0.028571   127.551020  9.921600e-07
# 213459            0.000042  0.000001    0.028571   680.272109  9.985300e-07
# 213460            0.000087  0.000002    0.057143   656.814450  1.996955e-06
# 213463            0.000175  0.000001    0.028571   163.265306  9.938750e-07
# 213465            0.000126  0.000001    0.028571   226.757370  9.955900e-07
# 224013            0.000025  0.000001    0.028571  1142.857143  9.991250e-07
# 235205            0.000029  0.000001    0.028571   985.221675  9.989850e-07
# 238930            0.000024  0.000001    0.028571  1190.476190  9.991600e-07
# 250036            0.000014  0.000001    0.028571  2040.816327  9.995100e-07
# 267367            0.000013  0.000001    0.028571  2197.802198  9.995450e-07
# 276505            0.000019  0.000001    0.028571  1503.759398  9.993350e-07
# 296333            0.000026  0.000002    0.057143  2197.802198  1.999090e-06
# 301659            0.000021  0.000002    0.057143  2721.088435  1.999265e-06
# 306823            0.000022  0.000001    0.028571  1298.701299  9.992300e-07
# 320067            0.000017  0.000001    0.028571  1680.672269  9.994050e-07
# 324956            0.000017  0.000001    0.028571  1680.672269  9.994050e-07
# 347094            0.000013  0.000001    0.028571  2197.802198  9.995450e-07
# 348427            0.000014  0.000002    0.057143  4081.632653  1.999510e-06
# 349068            0.000014  0.000001    0.028571  2040.816327  9.995100e-07
#
#         conviction
# 0         1.093729
# 20764     1.029390
# 73285     1.029391
# 149971    1.029380
# 158652    1.060586
# 213300    1.060577
# 213439    1.060546
# 213441    1.029374
# 213443    1.029173
# 213444    1.029277
# 213447    1.029372
# 213449    1.060499
# 213451    1.029364
# 213453    1.029350
# 213455    1.029348
# 213456    1.029181
# 213459    1.029369
# 213460    1.060514
# 213463    1.029232
# 213465    1.029282
# 224013    1.029386
# 235205    1.029382
# 238930    1.029387
# 250036    1.029397
# 267367    1.029398
# 276505    1.029392
# 296333    1.060578
# 301659    1.060584
# 306823    1.029389
# 320067    1.029394
# 324956    1.029394
# 347094    1.029398
# 348427    1.060591
# 349068    1.029397

# %%
class CoAuthors:
    def __init__(self, association_rules, top_n):
        self.association_rules = association_rules
        self.top_n = top_n

    def predict(self, author):
        return [
            coauthor
            for coauthors in self.association_rules[self.association_rules.antecedents.eq({author})].nlargest(self.top_n, 'lift').consequents
            for coauthor in coauthors
        ]

# %%
co_authors = CoAuthors(res_rules, 10)

# %%
co_authors.predict('Yunquan Zhang')
# Out:
# ['Wang Lei',
#  'Huiyang Zhou',
#  'Xiaodi Huang',
#  'Guoliang Chen',
#  'Tao Luo',
#  'Chen Ding',
#  'Chao Li',
#  'Chao Yang',
#  'Ke Wang',
#  'Ting Wang']

# %%
import pickle
with open('coauthors_model', 'wb') as picklefile:
    pickle.dump(co_authors, picklefile)
